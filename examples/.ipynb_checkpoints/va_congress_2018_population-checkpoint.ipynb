# %% [markdown]
# Need to aggregate the 2018 population data from the ACS at the block-group level to the 2018 precinct-level election results shapefile. I downloaded both from IPUMS, so this should be a simple join.

# %%
import geopandas
import pandas as pd

# read in blocks shapefile
bg = geopandas.read_file("zip://C:/Users/madie/OneDrive/data/ipums/VA_blck_grp_2018.zip")

# keep only the useful cols
bg = bg[["GISJOIN", "STATEFP", "COUNTYFP", "BLKGRPCE", "GEOID", "geometry"]].copy()

# read in population data csv
data = pd.read_csv("C:/Users/madie/OneDrive/data/ipums/va_bg_2018_data.zip")

# keep only the relevant columns for total population
data = data[["GISJOIN", "AJV9E001"]].copy()

# rename these cols to something more intelligible
data.columns = ["GISJOIN", "pop"]

# merge the population data into the blocks shapefile
bg = bg.merge(data, on='GISJOIN')

# %%
bg.head()
# Out:
#            GISJOIN STATEFP COUNTYFP BLKGRPCE         GEOID  \
# 0  G51000100901001      51      001        1  510010901001
# 1  G51000100901002      51      001        2  510010901002
# 2  G51000100901003      51      001        3  510010901003
# 3  G51000100901004      51      001        4  510010901004
# 4  G51000100902001      51      001        1  510010902001
#
#                                             geometry   pop
# 0  MULTIPOLYGON (((1781384.119 243080.884, 178137...  60.0
# 1  POLYGON ((1782731.187 242733.316, 1782702.147 ...  60.0
# 2  MULTIPOLYGON (((1781920.301 240213.966, 178191...  60.0
# 3  MULTIPOLYGON (((1780346.252 237655.516, 178035...  40.0
# 4  POLYGON ((1767188.764 240954.662, 1767173.531 ...  30.0

# %%
# write bg to file
bg.to_file("C:/Users/madie/OneDrive/data/ipums/va_bg_2018_pop/va_bg_2018_pop.shp")

# %%
precincts = geopandas.read_file("C:/Users/madie/OneDrive/data/vest/va_2018_ushouse/va_2018_ushouse.shp")

# %%
precincts.head()
# Out:
#   COUNTYFP         LOCALITY   VTDST        PRECINCT CON_DIST  G18HORDEM  \
# 0      001  Accomack County  000101    Chincoteague        2        533
# 1      001  Accomack County  000201        Atlantic        2        171
# 2      001  Accomack County  000202  Greenbackville        2        307
# 3      001  Accomack County  000301      New Church        2        583
# 4      001  Accomack County  000401          Bloxom        2        118
#
#    G18HORREP  G18HORLIB  G18HORWRI  \
# 0       1039          0          1
# 1        482          0          2
# 2        595          0          1
# 3        490          0          0
# 4        286          0          0
#
#                                             geometry
# 0  POLYGON Z ((-75.42507 37.89957 0.00000, -75.42...
# 1  POLYGON Z ((-75.59978 37.87664 0.00000, -75.59...
# 2  POLYGON Z ((-75.49919 37.93416 0.00000, -75.49...
# 3  POLYGON Z ((-75.64987 37.92702 0.00000, -75.64...
# 4  POLYGON Z ((-75.71556 37.87513 0.00000, -75.71...

# %%
precincts.crs
# Out:
# <Geographic 2D CRS: EPSG:4269>
# Name: NAD83
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: North America - onshore and offshore: Canada - Alberta; British Columbia; Manitoba; New Brunswick; Newfoundland and Labrador; Northwest Territories; Nova Scotia; Nunavut; Ontario; Prince Edward Island; Quebec; Saskatchewan; Yukon. Puerto Rico. United States (USA) - Alabama; Alaska; Arizona; Arkansas; California; Colorado; Connecticut; Delaware; Florida; Georgia; Hawaii; Idaho; Illinois; Indiana; Iowa; Kansas; Kentucky; Louisiana; Maine; Maryland; Massachusetts; Michigan; Minnesota; Mississippi; Missouri; Montana; Nebraska; Nevada; New Hampshire; New Jersey; New Mexico; New York; North Carolina; North Dakota; Ohio; Oklahoma; Oregon; Pennsylvania; Rhode Island; South Carolina; South Dakota; Tennessee; Texas; Utah; Vermont; Virginia; Washington; West Virginia; Wisconsin; Wyoming. US Virgin Islands.  British Virgin Islands.
# - bounds: (167.65, 14.92, -47.74, 86.46)
# Datum: North American Datum 1983
# - Ellipsoid: GRS 1980
# - Prime Meridian: Greenwich

# %%
bg.crs
# Out:
# <Projected CRS: ESRI:102003>
# Name: USA_Contiguous_Albers_Equal_Area_Conic
# Axis Info [cartesian]:
# - [east]: Easting (metre)
# - [north]: Northing (metre)
# Area of Use:
# - undefined
# Coordinate Operation:
# - name: unnamed
# - method: Albers Equal Area
# Datum: North American Datum 1983
# - Ellipsoid: GRS 1980
# - Prime Meridian: Greenwich

# %%
bg = bg.to_crs("EPSG:4269")

# %%
bg.crs
# Out:
# <Geographic 2D CRS: EPSG:4269>
# Name: NAD83
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: North America - onshore and offshore: Canada - Alberta; British Columbia; Manitoba; New Brunswick; Newfoundland and Labrador; Northwest Territories; Nova Scotia; Nunavut; Ontario; Prince Edward Island; Quebec; Saskatchewan; Yukon. Puerto Rico. United States (USA) - Alabama; Alaska; Arizona; Arkansas; California; Colorado; Connecticut; Delaware; Florida; Georgia; Hawaii; Idaho; Illinois; Indiana; Iowa; Kansas; Kentucky; Louisiana; Maine; Maryland; Massachusetts; Michigan; Minnesota; Mississippi; Missouri; Montana; Nebraska; Nevada; New Hampshire; New Jersey; New Mexico; New York; North Carolina; North Dakota; Ohio; Oklahoma; Oregon; Pennsylvania; Rhode Island; South Carolina; South Dakota; Tennessee; Texas; Utah; Vermont; Virginia; Washington; West Virginia; Wisconsin; Wyoming. US Virgin Islands.  British Virgin Islands.
# - bounds: (167.65, 14.92, -47.74, 86.46)
# Datum: North American Datum 1983
# - Ellipsoid: GRS 1980
# - Prime Meridian: Greenwich

# %% [markdown]
# Now, using `maup`, I need to disaggregate the block level population data and then reaggregate to the block level. aggregate the block group population data into the precinct file.

# %%
blocks = geopandas.read_file("zip://C:/Users/madie/OneDrive/data/ipums/VA_block_2010_pop.zip")

# %%
import maup
import warnings

# turn off annoying geoseries isna warnings
warnings.filterwarnings('ignore', 'GeoSeries.isna', UserWarning)
# enable progress bar
maup.progress.enabled = True

# change crs of shp files to be projected (using VA north)
blocks = blocks.to_crs(epsg=2283)
bg = bg.to_crs(epsg=2283)

# remove any bowties (little imperfections in the polygons)
blocks.geometry = blocks.buffer(0)
bg.geometry = bg.buffer(0)

blocks = blocks.reset_index(drop = True)
bg = bg.reset_index(drop = True)

# %%
# assign blocks to block groups
pop_cols = ["pop"]
assignment = maup.assign(blocks, bg)
# We prorate the population totals according to each block's share of the overall
# block group population:
denom = assignment.map(bg["pop"])
weights = blocks["pop"] / denom
prorated = maup.prorate(assignment, bg[pop_cols], weights)

# Add the prorated vote totals as columns on the `blocks` GeoDataFrame:
blocks[pop_cols] = prorated
blocks.to_file("C:/Users/madie/OneDrive/data/ipums/VA_block_2018_data/VA_block_2018_data.shp")
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████| 5321/5321 [03:08<00:00, 28.29it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████| 5321/5321 [03:44<00:00, 23.75it/s]

# %%
# cols to aggregate from blocks to precincts
variables = ['pop']
with maup.progress():
    assignment = maup.assign(bg, precincts)
precincts[variables] = bg[variables].groupby(assignment).sum()
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████| 2463/2463 [00:10<00:00, 226.34it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████| 2463/2463 [01:52<00:00, 21.96it/s]

# %% [markdown]
# Now that I've disaggregated by prorating the population data from the block groups down to blocks, I should be able to aggregate the population data from the blocks to the precincts.

# %%
precincts.head()
# Out:
#   COUNTYFP         LOCALITY   VTDST        PRECINCT CON_DIST  G18HORDEM  \
# 0      001  Accomack County  000101    Chincoteague        2        533
# 1      001  Accomack County  000201        Atlantic        2        171
# 2      001  Accomack County  000202  Greenbackville        2        307
# 3      001  Accomack County  000301      New Church        2        583
# 4      001  Accomack County  000401          Bloxom        2        118
#
#    G18HORREP  G18HORLIB  G18HORWRI  \
# 0       1039          0          1
# 1        482          0          2
# 2        595          0          1
# 3        490          0          0
# 4        286          0          0
#
#                                             geometry    pop
# 0  POLYGON Z ((12370063.644 6661341.644 0.000, 12...  220.0
# 1  POLYGON Z ((12319939.723 6651354.425 0.000, 12...   30.0
# 2  POLYGON Z ((12348275.656 6673222.628 0.000, 12...    NaN
# 3  POLYGON Z ((12304918.630 6669238.329 0.000, 12...    NaN
# 4  POLYGON Z ((12286550.849 6649769.089 0.000, 12...    NaN

# %%
blocks.head()
# Out:
#            GEOID10             GISJOIN      NAME10    pop  vap  TotPop  \
# 0  510050701003000  G51000500701003000  Block 3000   97.0   79      97
# 1  510050701003030  G51000500701003030  Block 3030    6.0    6       6
# 2  510050701004060  G51000500701004060  Block 4060  228.0  148     228
# 3  510050801003038  G51000500801003038  Block 3038   17.0   12      17
# 4  510050801003030  G51000500801003030  Block 3030    0.0    0       0
#
#    BlackPop  HispPop  VAP_1  BlackVAP  HispVAP  \
# 0         1        0     79         1        0
# 1         1        0      6         1        0
# 2        42        0    148        23        0
# 3         0        0     12         0        0
# 4         0        0      0         0        0
#
#                                             geometry
# 0  POLYGON ((11101620.475 6623881.065, 11101595.4...
# 1  POLYGON ((11100810.092 6623152.306, 11100711.5...
# 2  POLYGON ((11106206.406 6619274.633, 11106120.9...
# 3  POLYGON ((11093993.471 6615571.788, 11093726.5...
# 4  POLYGON ((11094729.812 6616563.293, 11094735.9...
