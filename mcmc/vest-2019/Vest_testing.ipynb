# %% [markdown]
# The Voting and Election Science Team at Harvard has some datasets for the years 2015, 2017, 2019 in VA, and I'm trying to find out what I will need to add.

# %%
library(sf)
library(ggplot2)
library(tidyverse)
library(tibble)
library(magrittr)
library(redist)
# Out:
# Linking to GEOS 3.8.0, GDAL 3.0.4, PROJ 6.3.1
#
# -- Attaching packages ------------------------------------------------------------------------------- tidyverse 1.3.0 --
#
# v tibble  3.0.4     v dplyr   1.0.2
# v tidyr   1.1.2     v stringr 1.4.0
# v readr   1.4.0     v forcats 0.5.0
# v purrr   0.3.4
#
# -- Conflicts ---------------------------------------------------------------------------------- tidyverse_conflicts() --
# x dplyr::filter() masks stats::filter()
# x dplyr::lag()    masks stats::lag()
#
#
# Attaching package: 'magrittr'
#
#
# The following object is masked from 'package:purrr':
#
#     set_names
#
#
# The following object is masked from 'package:tidyr':
#
#     extract

# %%
df19 <- st_read("C:/Users/madie/OneDrive/data/VA-2019/va_2019_statehouse.shp")
head(df19)
# Out:
# Reading layer `va_2019_statehouse' from data source `C:\Users\madie\OneDrive\data\VA-2019\va_2019_statehouse.shp' using driver `ESRI Shapefile'
# Simple feature collection with 2586 features and 5 fields
# geometry type:  MULTIPOLYGON
# dimension:      XYZ
# bbox:           xmin: -83.67539 ymin: 36.54085 xmax: -75.16643 ymax: 39.46601
# z_range:        zmin: 0 zmax: 0
# geographic CRS: NAD83
#   COUNTYFP LOCALITY        VTDST  PRECINCT       HOD_DIST
# 1 001      Accomack County 000101 Chincoteague   100
# 2 001      Accomack County 000201 Atlantic       100
# 3 001      Accomack County 000202 Greenbackville 100
# 4 001      Accomack County 000301 New Church     100
# 5 001      Accomack County 000401 Bloxom         100
# 6 001      Accomack County 000402 Parksley       100
#   geometry
# 1 MULTIPOLYGON Z (((-75.40929...
# 2 MULTIPOLYGON Z (((-75.41651...
# 3 MULTIPOLYGON Z (((-75.41651...
# 4 MULTIPOLYGON Z (((-75.49376...
# 5 MULTIPOLYGON Z (((-75.59939...
# ...

# %%
df17 <- st_read("C:/Users/madie/OneDrive/data/VA-2017-vest/va_2017_statehouse.shp")
head(df17)
# Out:
# Reading layer `va_2017_statehouse' from data source `C:\Users\madie\OneDrive\data\VA-2017-vest\va_2017_statehouse.shp' using driver `ESRI Shapefile'
# Simple feature collection with 2585 features and 11 fields
# geometry type:  MULTIPOLYGON
# dimension:      XYZ
# bbox:           xmin: -83.67539 ymin: 36.54085 xmax: -75.16643 ymax: 39.46601
# z_range:        zmin: 0 zmax: 0
# geographic CRS: NAD83
#   COUNTYFP LOCALITY        VTDST  PRECINCT       HOD_DIST G17HODDEM G17HODREP
# 1 001      Accomack County 000101 Chincoteague   100      357       879
# 2 001      Accomack County 000201 Atlantic       100      107       447
# 3 001      Accomack County 000202 Greenbackville 100      202       493
# 4 001      Accomack County 000301 New Church     100      362       418
# 5 001      Accomack County 000401 Bloxom         100       70       263
# 6 001      Accomack County 000402 Parksley       100      128       429
#   G17HODIND G17HODLIB G17HODGRE G17HODWRI geometry
# ...

# %%
df15 <- st_read("C:/Users/madie/OneDrive/data/VA-2015/va_2015_statehouse.shp")
head(df15)
# Out:
# Reading layer `va_2015_statehouse' from data source `C:\Users\madie\OneDrive\data\VA-2015\va_2015_statehouse.shp' using driver `ESRI Shapefile'
# Simple feature collection with 2577 features and 11 fields
# geometry type:  MULTIPOLYGON
# dimension:      XYZ
# bbox:           xmin: -83.67539 ymin: 36.54085 xmax: -75.16643 ymax: 39.46601
# z_range:        zmin: 0 zmax: 0
# geographic CRS: NAD83
#   COUNTYFP LOCALITY         VTDST  PRECINCT        HOD_DIST G15HODDEM G15HODREP
# 1 003      Albemarle County 000202 University Hall 057      221         0
# 2 001      Accomack County  000101 Chincoteague    100      178       703
# 3 001      Accomack County  000201 Atlantic        100       67       339
# 4 001      Accomack County  000202 Greenbackville  100       97       306
# 5 001      Accomack County  000301 Oak Hall        100      221       269
# 6 001      Accomack County  000401 Bloxom          100       48       215
#   G15HODIND G15HODLIB G15HODGRE G15HODWRI geometry
# ...

# %% [markdown]
# Ok, so in summary, this is the state of these three years.
#
# - 2019:
#     - Precinct shapefiles: YES
#     - Voting results: NO
#         - Can be added by me pivotting in the official data from the VA department of elections
#     - Population data: NO
#         - need to sort this out
# - 2017:
#     - Precinct shapefiles: YES
#     - Voting results: YES
#     - Population data: NO
#         - MGGG has already taken care of this, could just use that
# - 2015:
#     - Precinct shapefiles: YES
#     - Voting results: YES
#     - Population data: NO
#         - need to sort this out
