# %%
## Load data
library(redist)
data("fl25")
data("algdat.p10")
cds <- algdat.p10$cdmat[,100]
redist.map(shp=fl25, district_membership=cds, centroids=FALSE, edges=TRUE, drop=TRUE)
# Out:
# Warning message in CRS(proj4string):
# "CRS: projargs should not be NULL; set to NA"
# plot without title
