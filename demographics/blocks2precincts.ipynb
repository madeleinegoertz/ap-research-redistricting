# %% [markdown]
# ## Maup tests
#
# I need to figure out some way to aggregate data from the IPUMS from the block level to the precinct level.

# %%
import geopandas
import pandas

blocks = geopandas.read_file("zip://C:/Users/madie/OneDrive/data/maup/blocks.zip")
precincts = geopandas.read_file("zip://C:/Users/madie/OneDrive/data/maup/precincts.zip")
districts = geopandas.read_file("zip://C:/Users/madie/OneDrive/data/maup/districts.zip")

# %%
print(districts)
# Out:
#       id                                           geometry
# 0    1.0  POLYGON ((-71.38867 41.81894, -71.38864 41.818...
# 1    2.0  POLYGON ((-71.40391 41.82282, -71.40536 41.822...
# 2    3.0  POLYGON ((-71.41032 41.83659, -71.41048 41.836...
# 3    4.0  POLYGON ((-71.41118 41.84013, -71.41123 41.839...
# 4    5.0  POLYGON ((-71.46783 41.83388, -71.46822 41.833...
# 5    6.0  POLYGON ((-71.44372 41.82480, -71.44381 41.824...
# 6    7.0  POLYGON ((-71.45721 41.80562, -71.45777 41.805...
# 7    8.0  POLYGON ((-71.43357 41.78659, -71.43370 41.786...
# 8    9.0  POLYGON ((-71.42043 41.78771, -71.42051 41.787...
# 9   10.0  POLYGON ((-71.39825 41.78601, -71.39829 41.786...
# 10  11.0  POLYGON ((-71.43454 41.80832, -71.43507 41.807...
# 11  12.0  POLYGON ((-71.40906 41.82749, -71.40955 41.827...
# 12  13.0  POLYGON ((-71.43513 41.81013, -71.43550 41.810...
# 13  14.0  POLYGON ((-71.42817 41.84433, -71.42789 41.843...
# 14  15.0  POLYGON ((-71.45220 41.80620, -71.45233 41.806...

# %%
va_blocks = geopandas.read_file("zip://C:/Users/madie/OneDrive/data/census-shp/va_block_2010.zip")

# %%
print(va_blocks)
# Out:
#        STATEFP10 COUNTYFP10 TRACTCE10 BLOCKCE10          GEOID10      NAME10  \
# 0             51        141    030200      2069  511410302002069  Block 2069
# 1             51        141    030200      2140  511410302002140  Block 2140
# 2             51        141    030200      2054  511410302002054  Block 2054
# 3             51        141    030200      2078  511410302002078  Block 2078
# 4             51        141    030200      2057  511410302002057  Block 2057
# ...          ...        ...       ...       ...              ...         ...
# 285757        51        520    020400      2002  515200204002002  Block 2002
# 285758        51        520    020400      3017  515200204003017  Block 3017
# 285759        51        520    020200      1015  515200202001015  Block 1015
# 285760        51        520    020400      1025  515200204001025  Block 1025
# 285761        51        520    020400      1023  515200204001023  Block 1023
#
# ...

# %%
va_county_sub = geopandas.read_file("zip://C:/Users/madie/OneDrive/data/census-shp/va_county_sub_2019.zip")
print(va_county_sub)
# Out:
#     STATEFP COUNTYFP COUSUBFP  COUSUBNS       GEOID            NAME  \
# 0        51      137    91411  01927209  5113791411               2
# 1        51      137    91861  01927271  5113791861               5
# 2        51      137    91561  01927230  5113791561               3
# 3        51      047    90680  01927134  5104790680  Cedar Mountain
# 4        51      047    95535  01927483  5104795535           Salem
# ..      ...      ...      ...       ...         ...             ...
# 547      51      137    91711  01927250  5113791711               4
# 548      51      720    94931  01498434  5172094931          Norton
# 549      51      031    90032  01927076  5103190032       Altavista
# 550      51      031    90504  01927117  5103190504       Brookneal
# 551      51      031    96015  01927532  5103196015        Sunburst
#
#                     NAMELSAD LSAD CLASSFP  MTFCC CNECTAFP NECTAFP NCTADVFP  \
# ...

# %%
va_county_sub.plot()

# %%
va_vtd = geopandas.read_file("zip://C:/Users/madie/OneDrive/data/census-shp/va_vtd_2010.zip")
print(va_county_sub)
# Out:
#     STATEFP COUNTYFP COUSUBFP  COUSUBNS       GEOID            NAME  \
# 0        51      137    91411  01927209  5113791411               2
# 1        51      137    91861  01927271  5113791861               5
# 2        51      137    91561  01927230  5113791561               3
# 3        51      047    90680  01927134  5104790680  Cedar Mountain
# 4        51      047    95535  01927483  5104795535           Salem
# ..      ...      ...      ...       ...         ...             ...
# 547      51      137    91711  01927250  5113791711               4
# 548      51      720    94931  01498434  5172094931          Norton
# 549      51      031    90032  01927076  5103190032       Altavista
# 550      51      031    90504  01927117  5103190504       Brookneal
# 551      51      031    96015  01927532  5103196015        Sunburst
#
#                     NAMELSAD LSAD CLASSFP  MTFCC CNECTAFP NECTAFP NCTADVFP  \
# ...
