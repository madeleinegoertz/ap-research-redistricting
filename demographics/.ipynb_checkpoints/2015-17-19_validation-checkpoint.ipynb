# %%
# %config IPCompleter.greedy=True

import geopandas

df = geopandas.read_file("zip://C:/Users/madie/OneDrive/data/pre-redist/VA_precinct_2015.zip")

# %%
df.head()
# Out:
#   COUNTYFP          LOCALITY   VTDST         PRECINCT HOD_DIST  G15HODDEM  \
# 0      003  Albemarle County  000202  University Hall      057        221
# 1      001   Accomack County  000101     Chincoteague      100        178
# 2      001   Accomack County  000201         Atlantic      100         67
# 3      001   Accomack County  000202   Greenbackville      100         97
# 4      001   Accomack County  000301         Oak Hall      100        221
#
#    G15HODREP  G15HODIND  G15HODLIB  G15HODGRE  G15HODWRI     pop  TotPop  \
# 0          0          0          0          0          5  2214.0  2214.0
# 1        703          0          0          0          2  1122.0  1122.0
# 2        339          0          0          0          0   353.0   353.0
# 3        306          0          0          0          0   745.0   745.0
# 4        269          0          0          0          0   819.0   819.0
#
#      BlackPop    HispPop          VAP    BlackVAP    HISPVAP  \
# ...

# %%
df.plot()

# %%
df.head(100)
# Out:
#    COUNTYFP          LOCALITY   VTDST         PRECINCT HOD_DIST  G15HODDEM  \
# 0       003  Albemarle County  000202  University Hall      057        221
# 1       001   Accomack County  000101     Chincoteague      100        178
# 2       001   Accomack County  000201         Atlantic      100         67
# 3       001   Accomack County  000202   Greenbackville      100         97
# 4       001   Accomack County  000301         Oak Hall      100        221
# ..      ...               ...     ...              ...      ...        ...
# 95      013  Arlington County  000050    Crystal Plaza      048        276
# 96      013  Arlington County  000018        Park Lane      047        534
# 97      013  Arlington County  000039          Ashlawn      047        391
# 98      013  Arlington County  000049           Monroe      047        314
# 99      013  Arlington County  000022         Abingdon      045        623
#
# ...

# %%
df.
