# %%
import geopandas
df15 = geopandas.read_file("zip://C:/Users/madie/OneDrive/data/pre-redist/VA_precinct_2015.zip")
df17 = geopandas.read_file("zip://C:/Users/madie/OneDrive/data/pre-redist/VA_precinct_2017.zip")
df19 = geopandas.read_file("zip://C:/Users/madie/OneDrive/data/pre-redist/VA_precinct_2019.zip")
df15.plot()
df17.plot()
df19.plot()
